# %%
import bydoux_tools as bt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table
import os
from astropy.time import Time
#import datetime

import bydoux_tools as bt
from bydoux_tools import printc
# get today's date
import datetime
# import ius
from scipy.interpolate import UnivariateSpline as ius
from wpca import PCA
from scipy.special import erf

# %%
def simu_sp500(nkeeps=[10], timesteps=[45], lookback_scales=[7], method='slope', injection=30000, nyears=20, doplot=True):

    tickers0 = bt.get_snp500()
    tickers = np.array(tickers0)

    lookbacks = np.array(timesteps) * np.array(lookback_scales)


    today = bt.today()

    tbl = Table()
    tbl['nkeeps'] = nkeeps
    tbl['timestep'] = timesteps
    tbl['lookback_scale'] = lookback_scales
    tbl['method'] = method
    tbl['mean_growth_nothing'] = np.nan
    tbl['mean_growth_strategy'] = np.nan
    tbl['rms_nothing'] = np.nan
    tbl['rms_strategy'] = np.nan
    all_gains_keep = []


    for nth_simu in range(len(nkeeps)):
        all_sp500 = bt.batch_quotes('S&P500', force=False)

        nkeep = nkeeps[nth_simu]
        timestep = timesteps[nth_simu]
        lookback_scale = lookback_scales[nth_simu]
        lookback = lookbacks[nth_simu]

        scenario_name = f'{timestep}days_{lookback}days_{nyears}years_{nkeep}stocks_{method}'

        t_decision = Time(datetime.datetime.now()).mjd - np.arange(0, 365 * nyears, timestep)

        tmax = all_sp500[tickers[0]]['mjd'][-1]


        growth_nothing = np.zeros(len(t_decision))
        growth_strategy = np.zeros(len(t_decision))

        t_decision = t_decision[np.argsort(t_decision)]


        sectors_ini = []
        # get all sectors:
        for ticker in tickers:
            try:
                info = bt.get_info(ticker)
                sect = info['sector']
                printc(f'{ticker}, sector {sect}')
                sectors_ini.append(info['sector'])
            except:
                sectors_ini.append('Unknown')

        sectors_ini = np.array(sectors_ini)

        dict_gains = {}
        for imc in range(len(t_decision)):
            kept_keys = []
            gains = []
            slopes = []
            sigmas = []
            sectors = []

            tickers = np.array(tickers0)

            for iticker in range(len(tickers)):
                ticker = tickers[iticker]

                if ticker not in all_sp500.keys():
                    continue

                tbl1 = dict(all_sp500[ticker])
                if len(tbl1['date'])<100:
                    continue


                t1 = t_decision[imc] - lookback#[nth_simu]
                t2 = t_decision[imc]+timestep#[nth_simu]

                time_valid = (tbl1['mjd']>t1) & (tbl1['mjd']<t2)
                if np.sum(time_valid)<0.5*lookback:
                    continue

                for key_tbl in tbl1.keys():
                    tbl1[key_tbl] = tbl1[key_tbl][time_valid]

                dt = np.max(tbl1['mjd']) - tbl1['mjd']

                keep_for_fit = tbl1['mjd'] < t_decision[imc]
                keep_for_fit2 = (tbl1['mjd'] < t_decision[imc]) * (tbl1['mjd'] > (t_decision[imc] - timestep))
                
                if np.sum(keep_for_fit)<0.5*lookback:
                    continue

                if method == 'slope':
                    # error increases with lookback time
                    #tt = tbl1['mjd'][keep_for_fit] #/ 365.25
                    #tt = np.abs(tt - np.max(tt))
                    #w=1/(tt+lookback)
                    #w/=w[-1]


                    
                    #tt+=1
                    #sig = np.nanstd(tbl1['log_close'][keep_for_fit]) * np.sqrt(lookback_scale)
                    #fit = np.polyfit(tbl1['mjd'][keep_for_fit] / 365.25, tbl1['log_close'][keep_for_fit],1, w=w)
                    fit = np.polyfit(tbl1['mjd'][keep_for_fit] / 365.25, tbl1['log_close'][keep_for_fit],1)
                    fit2 = np.polyfit(tbl1['mjd'][keep_for_fit2] / 365.25, tbl1['log_close'][keep_for_fit2],1)
                    rms = (tbl1['log_close'][keep_for_fit] - np.polyval(fit, tbl1['mjd'][keep_for_fit] / 365.25))

                    sigma = np.nanmean(np.abs(rms))

                    slopes.append(fit[0]+fit2[0]*.2)
                    sigmas.append(sigma)

                elif method == 'mean':
                    slopes.append(tbl1['log_close'][keep_for_fit][-1] - np.nanmean(tbl1['log_close'][keep_for_fit][-1]))
                    sigmas.append(np.nanstd(tbl1['log_close'][keep_for_fit]))

                elif method == 'cheaper':
                    slopes.append( - tbl1['Close'][keep_for_fit][-1])
                    sigmas.append(np.nanstd(tbl1['log_close'][keep_for_fit]))


                last_iteration = (np.max(tbl1['mjd']) == t_decision[imc])

                if not last_iteration:
                    gain = tbl1['log_close'][-1]- tbl1['log_close'][keep_for_fit][-1]
                    gains.append(gain)
                else:
                    gains.append(np.nan)

                kept_keys.append(ticker)
                sectors.append(sectors_ini[iticker])

                outname = '/Users/eartigau/pydoux_data/quotes/' + ticker + '_' + today + '.csv'


            slopes = np.array(slopes)
            sigmas = np.array(sigmas)
            gains = np.array(gains)
            keys = np.array(kept_keys)
            sectors = np.array(sectors)


            # we keep only the best nkeep stocks
            ord = np.argsort(slopes)[::-1]

            # we reorder the arrays according to the order vector
            gains_keep = gains[ord]#[0:nkeep]
            slopes_keep = slopes[ord]#[0:nkeep]
            sigmas_keep = sigmas[ord]#[0:nkeep]
            keys_keep = keys[ord]#[0:nkeep]
            sectors_keep = sectors[ord]#[0:nkeep]

            if True:
                keep = np.array([False]*len(gains_keep))

                usector =  np.unique(sectors_keep)
                for sector in usector:
                    mask = sectors_keep == sector
                    if np.sum(mask)<3:
                        continue

                    tmp = keep[mask]
                    nmax = nkeep//4
                    tmp[0:nmax] = True
                    keep[mask] = tmp

                gains_keep = gains_keep[keep]
                slopes_keep = slopes_keep[keep]
                sigmas_keep = sigmas_keep[keep]
                keys_keep = keys_keep[keep]
                sectors_keep = sectors_keep[keep]

            prob_gain = np.zeros(len(gains_keep))+0.04
            for i in range(len(gains_keep)):
                if keys_keep[i] in dict_gains.keys():
                    prob_gain[i] = np.nanmean(dict_gains[keys_keep[i]])

            ord = np.argsort(keys_keep)
            gains_keep = gains_keep[0:nkeep]
            slopes_keep = slopes_keep[0:nkeep]
            sigmas_keep = sigmas_keep[0:nkeep]
            keys_keep = keys_keep[0:nkeep]
            sectors_keep = sectors_keep[0:nkeep]
            prob_gain = prob_gain[0:nkeep]

            all_gains_keep.append(gains_keep)

            #ww = erf((prob_gain-np.mean(prob_gain))/0.05)*0.5+0.5
            #ww[ww<0] = 0
            ##ww[ww>np.nanmedian(ww)] = 2*np.nanmedian(ww)
            #ww/=np.mean(ww)

            for key in keys_keep:
                if key not in dict_gains.keys():
                    dict_gains[key] = []
                dict_gains[key].append(gains_keep[np.where(keys_keep == key)[0][0]])
            

            printc('~'*80)
            #os.system('clear')

            t_year = (t_decision[imc] - Time('2000-01-01').mjd) / 365.25 + 2000

            time_str= Time(t_decision[imc],format='mjd').iso.split(' ')[0]
            printc(f'Simulation {nth_simu+1}/{len(nkeeps)}')
            print(f'Date : {time_str}')
            printc(f'Year : {t_year:.2f}')
            gain1 = np.nanmean(np.exp(gains)) #** (365 / dt2)
            printc(f'gain/{timestep:.0f} days doing nothing, {gain1:.2f}')

            ww = np.ones_like(gains_keep)
            ww/=np.mean(ww)
            gain2 = np.nanmean(np.exp(gains_keep)*ww) #** (365 / dt2)
            printc(f'gain/{timestep:.0f} days with strategy, {gain2:.2f}')


            growth_nothing[imc] = gain1
            growth_strategy[imc] = gain2


            for i in range(len(gains_keep)):
                ptxt = keys_keep[i],np.exp(gains_keep[i]), np.exp(gains_keep[i] * (365 / timestep)), slopes_keep[i], sigmas_keep[i], \
                    slopes_keep[i] / sigmas_keep[i]
                strtxt = f'{ptxt[0]}\tgain/{timestep} days : {ptxt[1]:.2f} \t gain/year : {ptxt[2]:.2f} \t slope : {ptxt[3]:.2f} ' \
                        f'\t ' \
                        f'sigma :' \
                        f' {ptxt[4]:.2f} \t qual : {ptxt[5]:.2f}'
                printc(strtxt)
                printc(f'Sector : {sectors_keep[i]}')

        all_gains_histo = np.exp(np.array(all_gains_keep).ravel())
        plt.hist(all_gains_histo, bins=30, histtype='step', range=[0.6,1.8], fill=True)
        plt.xlabel('Growth in {} days'.format(timestep))
        plt.ylabel('Number of stocks')
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.show()

        if doplot:
            vv = np.array([growth_nothing,growth_strategy])
            vv = vv.ravel()
            vv = vv[np.isfinite(vv)]
            p1,p99 = np.percentile(vv,[1,99])
            prange = [p1,p99]
            width = p99-p1
            prange[0]-=0.1*width
            prange[1]+=0.1*width

            plt.hist(growth_nothing, bins=30, histtype='step', color='r', label='Nothing', range=prange, fill=True,
                    alpha =0.5)
            plt.hist(growth_strategy, bins=30, histtype='step', color='g', label='Strategy', alpha = 0.5, fill=True, range=prange)
            plt.legend()
            plt.show()


        mean_growth_nothing = np.nanprod(growth_nothing)**(1/nyears)
        mean_growth_strategy = np.nanprod(growth_strategy)**(1/nyears)

        t_year = (t_decision - Time('2000-01-01').mjd)/365.25+2000

        t_year_plot = t_decision - Time('1970-01-01').mjd
        if doplot:
            plt.plot_date(t_year_plot, growth_nothing, 'r-')
            plt.plot_date(t_year_plot, growth_strategy, 'g-')
            plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
            plt.show()

        fit_nothing = np.polyfit(t_year,np.log(np.cumproduct(growth_nothing)),1)
        rms_nothing = np.nanstd(np.log(np.cumproduct(growth_nothing)) - np.polyval(fit_nothing,t_year))

        fit_strategy = np.polyfit(t_year,np.log(np.cumproduct(growth_strategy)),1)
        rms_strategy = np.nanstd(np.log(np.cumproduct(growth_strategy)) - np.polyval(fit_strategy,t_year))

        printc(f'Mean yearly growth doing nothing : {mean_growth_nothing:.2f}, rms : {rms_nothing:.2f}')
        printc(f'Mean yearly growth with strategy : {mean_growth_strategy:.2f}, rms : {rms_strategy:.2f}')

        tbl['mean_growth_nothing'][nth_simu] = mean_growth_nothing
        tbl['mean_growth_strategy'][nth_simu] = mean_growth_strategy
        tbl['rms_nothing'][nth_simu] = rms_nothing
        tbl['rms_strategy'][nth_simu] = rms_strategy

        uyear = np.unique(t_year.astype(int))
        year_mean_nothing = np.zeros(len(uyear))
        year_mean_strategy = np.zeros(len(uyear))
        for i, year in enumerate(uyear):
            mask = t_year.astype(int) == year
            year_mean_nothing[i] = np.prod(growth_nothing[mask])
            year_mean_strategy[i] = np.prod(growth_strategy[mask])

        if doplot:
            plt.plot_date(t_year_plot,np.log(np.cumproduct(growth_strategy)))
            plt.plot_date(t_year_plot,np.log(np.cumproduct(growth_nothing)))
            plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
            plt.show()


            plt.step(uyear,year_mean_nothing,'r',label='Nothing')
            plt.step(uyear,year_mean_strategy,'g',label='Strategy')
            plt.legend()
            plt.show()

            year_mean_strategy[year_mean_strategy<0.5] = 0.5
            year_mean_nothing[year_mean_nothing<0.5] = 0.5
            year_mean_nothing[year_mean_nothing>2] = 2
            year_mean_strategy[year_mean_strategy>2] = 2
            plt.hist(year_mean_strategy, bins=10, histtype='step', color='g', label='Strategy', range=[0.4,2], fill=True,
                    alpha =0.5)
            plt.hist(year_mean_nothing, bins=10, histtype='step', color='r', label='Nothing', range=[0.4,2], fill=True,
                    alpha =0.5)
            plt.legend()
            plt.show()


        printc(f'Fraction {np.sum(growth_strategy>1)/len(growth_strategy):.2f} of {timestep} days with positive growth [{np.sum(growth_strategy>1)}/{len(growth_strategy)}] -- '
                f'strategy')
        printc(f'Fraction {np.sum(growth_nothing>1)/len(growth_nothing):.2f} of {timestep} days with positive growth [{np.sum(growth_nothing>1)}/{len(growth_nothing)}] -- nothing')

        printc(f'Fraction {np.sum(year_mean_strategy>1)/len(year_mean_strategy):.2f} of yearly with positive growth [{np.sum(year_mean_strategy>1)}/{len(year_mean_strategy)}] -- '
            f'strategy')
        printc(f'Fraction {np.sum(year_mean_nothing>1)/len(year_mean_nothing):.2f} of yearly with positive growth [{np.sum(year_mean_nothing>1)}/{len(year_mean_nothing)}] -- nothing')
"""
nkeeps = [10]
timesteps = [45]
lookback_scales = [5]
method = 'slope'
injection = 30000
nyears = 15

"""




if __name__ == "__main__":
    #simu_sp500(nkeeps=[10], timesteps=[45], lookback_scales=[5], method='slope', injection=30000, nyears=25)    
    simu_sp500(nkeeps=[8], timesteps=[45], lookback_scales=[5], method='slope', injection=30000, nyears=20)
# Out:
# 15:16:06.357 |   input of MMM in batch_quotes
# 15:16:27.625 |   input of AOS in batch_quotes
# 15:16:43.331 |   input of ABT in batch_quotes
# 15:17:00.018 |   input of ABBV in batch_quotes
# 15:17:04.749 |   input of ACN in batch_quotes
# 15:17:16.826 |   input of ADBE in batch_quotes
# 15:17:33.107 |   input of AMD in batch_quotes
# 15:17:49.164 |   input of AES in batch_quotes
# 15:18:00.520 |   input of AFL in batch_quotes
# 15:18:18.932 |   input of A in batch_quotes
# 15:18:29.754 |   input of APD in batch_quotes
# 15:18:45.648 |   input of ABNB in batch_quotes
# 15:18:47.675 |   input of AKAM in batch_quotes
# 15:18:55.745 |   input of ALB in batch_quotes
# 15:19:04.891 |   input of ARE in batch_quotes
# 15:19:13.424 |   input of ALGN in batch_quotes
# 15:19:21.487 |   input of ALLE in batch_quotes
# 15:19:25.045 |   input of LNT in batch_quotes
# 15:19:40.126 |   input of ALL in batch_quotes
# 15:19:50.645 |   input of GOOGL in batch_quotes
# 15:19:57.383 |   input of GOOG in batch_quotes
# 15:20:03.018 |   input of MO in batch_quotes
# 15:20:22.190 |   input of AMZN in batch_quotes
# 15:20:30.306 |   input of AMCR in batch_quotes
# 15:20:34.018 |   input of AEE in batch_quotes
# 15:20:44.847 |   input of AEP in batch_quotes
# 15:21:03.549 |   input of AXP in batch_quotes
# 15:21:17.591 |   input of AIG in batch_quotes
# 15:21:30.090 |   input of AMT in batch_quotes
# 15:21:36.332 |   input of AWK in batch_quotes
# 15:21:41.240 |   input of AMP in batch_quotes
# 15:21:46.380 |   input of AME in batch_quotes
# 15:21:57.742 |   input of AMGN in batch_quotes
# 15:22:08.207 |   input of APH in batch_quotes
# 15:22:17.498 |   input of ADI in batch_quotes
# 15:22:33.232 |   input of ANSS in batch_quotes
# 15:22:42.214 |   input of AON in batch_quotes
# 15:22:54.729 |   input of APA in batch_quotes
# 15:23:08.712 |   input of APO in batch_quotes
# 15:23:15.142 |   input of AAPL in batch_quotes
# 15:23:27.229 |   input of AMAT in batch_quotes
# 15:23:39.461 |   input of APTV in batch_quotes
# 15:23:43.258 |   input of ACGL in batch_quotes
# 15:23:51.270 |   input of ADM in batch_quotes
# 15:24:04.345 |   input of ANET in batch_quotes
# 15:24:07.547 |   input of AJG in batch_quotes
# 15:24:18.903 |   input of AIZ in batch_quotes
# 15:24:24.673 |   input of T in batch_quotes
# 15:24:35.455 |   input of ATO in batch_quotes
# 15:24:47.207 |   input of ADSK in batch_quotes
# 15:24:58.332 |   input of ADP in batch_quotes
# 15:25:10.116 |   input of AZO in batch_quotes
# 15:25:18.954 |   input of AVB in batch_quotes
# 15:25:27.497 |   input of AVY in batch_quotes
# 15:25:41.113 |   input of AXON in batch_quotes
# 15:25:47.179 |   input of BKR in batch_quotes
# 15:25:58.560 |   input of BALL in batch_quotes
# 15:26:13.780 |   input of BAC in batch_quotes
# 15:26:28.217 |   input of BAX in batch_quotes
# 15:26:40.491 |   input of BDX in batch_quotes
# 15:26:56.450 |   input of BRK.B in batch_quotes
# $BRK.B: possibly delisted; no timezone found
# 15:27:00.929 |  failed for BRK.B
# 15:27:00.929 |   input of BBY in batch_quotes
# 15:27:11.900 |   input of TECH in batch_quotes
# 15:27:21.952 |   input of BIIB in batch_quotes
# 15:27:30.882 |   input of BLK in batch_quotes
# 15:27:37.865 |   input of BX in batch_quotes
# 15:27:42.961 |   input of BK in batch_quotes
# 15:27:58.148 |   input of BA in batch_quotes
# 15:28:15.400 |   input of BKNG in batch_quotes
# 15:28:23.222 |   input of BSX in batch_quotes
# 15:28:32.466 |   input of BMY in batch_quotes
# 15:28:47.939 |   input of AVGO in batch_quotes
# 15:28:53.065 |   input of BR in batch_quotes
# 15:28:59.115 |   input of BRO in batch_quotes
# $BF.B: possibly delisted; no price data found  (1d 1926-07-05 -> 2025-06-10)
# 15:29:12.037 |   input of BF.B in batch_quotes
# 15:29:12.195 |  failed for BF.B
# 15:29:12.196 |   input of BLDR in batch_quotes
# 15:29:18.681 |   input of BG in batch_quotes
# 15:29:25.799 |   input of BXP in batch_quotes
# 15:29:33.657 |   input of CHRW in batch_quotes
# 15:29:41.591 |   input of CDNS in batch_quotes
# 15:29:55.010 |   input of CZR in batch_quotes
# 15:29:58.627 |   input of CPT in batch_quotes
# 15:30:09.430 |   input of CPB in batch_quotes
# 15:30:26.708 |   input of COF in batch_quotes
# 15:30:36.197 |   input of CAH in batch_quotes
# 15:30:48.173 |   input of KMX in batch_quotes
# 15:30:56.426 |   input of CCL in batch_quotes
# 15:31:09.303 |   input of CARR in batch_quotes
# 15:31:11.477 |   input of CAT in batch_quotes
# 15:31:31.064 |   input of CBOE in batch_quotes
# 15:31:36.212 |   input of CBRE in batch_quotes
# 15:31:43.252 |   input of CDW in batch_quotes
# 15:31:46.714 |   input of COR in batch_quotes
# 15:31:55.337 |   input of CNC in batch_quotes
# 15:32:02.268 |   input of CNP in batch_quotes
# 15:32:20.973 |   input of CF in batch_quotes
# 15:32:26.144 |   input of CRL in batch_quotes
# 15:32:32.237 |   input of SCHW in batch_quotes
# 15:32:42.341 |   input of CHTR in batch_quotes
# 15:32:46.557 |   input of CVX in batch_quotes
# 15:33:05.447 |   input of CMG in batch_quotes
# 15:33:12.942 |   input of CB in batch_quotes
# 15:33:22.471 |   input of CHD in batch_quotes
# 15:33:36.886 |   input of CI in batch_quotes
# 15:33:50.879 |   input of CINF in batch_quotes
# 15:34:04.565 |   input of CTAS in batch_quotes
# 15:34:16.674 |   input of CSCO in batch_quotes
# 15:34:27.187 |   input of C in batch_quotes
# 15:34:41.926 |   input of CFG in batch_quotes
# 15:34:45.426 |   input of CLX in batch_quotes
# 15:35:00.863 |   input of CME in batch_quotes
# 15:35:07.195 |   input of CMS in batch_quotes
# 15:35:22.015 |   input of KO in batch_quotes
# 15:35:39.777 |   input of CTSH in batch_quotes
# 15:35:46.872 |   input of COIN in batch_quotes
# 15:35:48.018 |   input of CL in batch_quotes
# 15:36:00.498 |   input of CMCSA in batch_quotes
# 15:36:11.568 |   input of CAG in batch_quotes
# 15:36:23.267 |   input of COP in batch_quotes
# 15:36:33.361 |   input of ED in batch_quotes
# 15:36:48.358 |   input of STZ in batch_quotes
# 15:36:56.428 |   input of CEG in batch_quotes
# 15:36:57.522 |   input of COO in batch_quotes
# 15:37:07.194 |   input of CPRT in batch_quotes
# 15:37:15.069 |   input of GLW in batch_quotes
# 15:37:26.378 |   input of CPAY in batch_quotes
# 15:37:29.790 |   input of CTVA in batch_quotes
# 15:37:31.965 |   input of CSGP in batch_quotes
# 15:37:40.892 |   input of COST in batch_quotes
# 15:37:51.741 |   input of CTRA in batch_quotes
# 15:38:01.605 |   input of CRWD in batch_quotes
# 15:38:03.356 |   input of CCI in batch_quotes
# 15:38:10.725 |   input of CSX in batch_quotes
# 15:38:23.344 |   input of CMI in batch_quotes
# 15:38:37.030 |   input of CVS in batch_quotes
# 15:38:52.186 |   input of DHR in batch_quotes
# 15:39:05.068 |   input of DRI in batch_quotes
# 15:39:13.705 |   input of DVA in batch_quotes
# 15:39:21.045 |   input of DAY in batch_quotes
# 15:39:23.094 |   input of DECK in batch_quotes
# 15:39:32.799 |   input of DE in batch_quotes
# 15:39:48.030 |   input of DELL in batch_quotes
# 15:39:51.332 |   input of DAL in batch_quotes
# 15:39:57.147 |   input of DVN in batch_quotes
# 15:40:08.543 |   input of DXCM in batch_quotes
# 15:40:14.706 |   input of FANG in batch_quotes
# 15:40:18.681 |   input of DLR in batch_quotes
# 15:40:25.329 |   input of DG in batch_quotes
# 15:40:31.068 |   input of DLTR in batch_quotes
# 15:40:39.465 |   input of D in batch_quotes
# 15:40:54.642 |   input of DPZ in batch_quotes
# 15:41:00.757 |   input of DASH in batch_quotes
# 15:41:02.423 |   input of DOV in batch_quotes
# 15:41:19.719 |   input of DOW in batch_quotes
# 15:41:22.230 |   input of DHI in batch_quotes
# 15:41:38.716 |   input of DTE in batch_quotes
# 15:42:00.481 |   input of DUK in batch_quotes
# 15:42:14.748 |   input of DD in batch_quotes
# 15:42:30.191 |   input of EMN in batch_quotes
# 15:42:39.852 |   input of ETN in batch_quotes
# 15:42:54.830 |   input of EBAY in batch_quotes
# 15:43:02.139 |   input of ECL in batch_quotes
# 15:43:19.238 |   input of EIX in batch_quotes
# 15:43:35.191 |   input of EW in batch_quotes
# 15:43:42.831 |   input of EA in batch_quotes
# 15:43:53.253 |   input of ELV in batch_quotes
# 15:44:00.891 |   input of EMR in batch_quotes
# 15:44:15.936 |   input of ENPH in batch_quotes
# 15:44:19.987 |   input of ETR in batch_quotes
# 15:44:35.280 |   input of EOG in batch_quotes
# 15:44:47.318 |   input of EPAM in batch_quotes
# 15:44:53.307 |   input of EQT in batch_quotes
# 15:45:10.984 |   input of EFX in batch_quotes
# 15:45:27.325 |   input of EQIX in batch_quotes
# 15:45:35.783 |   input of EQR in batch_quotes
# 15:45:47.171 |   input of ERIE in batch_quotes
# 15:45:56.450 |   input of ESS in batch_quotes
# 15:46:06.298 |   input of EL in batch_quotes
# 15:46:15.043 |   input of EG in batch_quotes
# 15:46:24.639 |   input of EVRG in batch_quotes
# 15:46:38.872 |   input of ES in batch_quotes
# 15:46:52.662 |   input of EXC in batch_quotes
# 15:47:05.419 |   input of EXE in batch_quotes
# 15:47:06.745 |   input of EXPE in batch_quotes
# 15:47:12.925 |   input of EXPD in batch_quotes
# 15:47:24.693 |   input of EXR in batch_quotes
# 15:47:31.085 |   input of XOM in batch_quotes
# 15:47:50.104 |   input of FFIV in batch_quotes
# 15:47:57.243 |   input of FDS in batch_quotes
# 15:48:05.858 |   input of FICO in batch_quotes
# 15:48:15.321 |   input of FAST in batch_quotes
# 15:48:26.045 |   input of FRT in batch_quotes
# 15:48:39.702 |   input of FDX in batch_quotes
# 15:48:51.787 |   input of FIS in batch_quotes
# 15:48:58.021 |   input of FITB in batch_quotes
# 15:49:08.952 |   input of FSLR in batch_quotes
# 15:49:13.371 |   input of FE in batch_quotes
# 15:49:20.455 |   input of FI in batch_quotes
# 15:49:30.232 |   input of F in batch_quotes
# 15:49:46.190 |   input of FTNT in batch_quotes
# 15:49:50.162 |   input of FTV in batch_quotes
# 15:49:52.703 |   input of FOXA in batch_quotes
# 15:49:54.733 |   input of FOX in batch_quotes
# 15:49:56.738 |   input of BEN in batch_quotes
# 15:50:07.250 |   input of FCX in batch_quotes
# 15:50:14.756 |   input of GRMN in batch_quotes
# 15:50:21.212 |   input of IT in batch_quotes
# 15:50:28.557 |   input of GE in batch_quotes
# 15:50:43.973 |   input of GEHC in batch_quotes
# 15:50:44.864 |   input of GEV in batch_quotes
# 15:50:45.386 |   input of GEN in batch_quotes
# 15:50:56.428 |   input of GNRC in batch_quotes
# 15:51:01.283 |   input of GD in batch_quotes
# 15:51:17.086 |   input of GIS in batch_quotes
# 15:51:28.258 |   input of GM in batch_quotes
# 15:51:31.983 |   input of GPC in batch_quotes
# 15:51:43.341 |   input of GILD in batch_quotes
# 15:51:52.904 |   input of GPN in batch_quotes
# 15:52:01.060 |   input of GL in batch_quotes
# 15:52:14.040 |   input of GDDY in batch_quotes
# 15:52:18.162 |   input of GS in batch_quotes
# 15:52:26.038 |   input of HAL in batch_quotes
# 15:52:41.321 |   input of HIG in batch_quotes
# 15:52:51.488 |   input of HAS in batch_quotes
# 15:53:02.927 |   input of HCA in batch_quotes
# 15:53:06.407 |   input of DOC in batch_quotes
# 15:53:17.093 |   input of HSIC in batch_quotes
# 15:53:24.774 |   input of HSY in batch_quotes
# 15:53:37.963 |   input of HES in batch_quotes
# 15:53:48.847 |   input of HPE in batch_quotes
# 15:53:51.646 |   input of HLT in batch_quotes
# 15:53:54.713 |   input of HOLX in batch_quotes
# 15:54:03.220 |   input of HD in batch_quotes
# 15:54:12.950 |   input of HON in batch_quotes
# 15:54:26.822 |   input of HRL in batch_quotes
# 15:54:36.075 |   input of HST in batch_quotes
# 15:54:46.425 |   input of HWM in batch_quotes
# 15:54:48.485 |   input of HPQ in batch_quotes
# 15:55:04.637 |   input of HUBB in batch_quotes
# 15:55:17.780 |   input of HUM in batch_quotes
# 15:55:29.566 |   input of HBAN in batch_quotes
# 15:55:44.136 |   input of HII in batch_quotes
# 15:55:48.336 |   input of IBM in batch_quotes
# 15:56:07.035 |   input of IEX in batch_quotes
# 15:56:17.579 |   input of IDXX in batch_quotes
# 15:56:26.714 |   input of ITW in batch_quotes
# 15:56:40.030 |   input of INCY in batch_quotes
# 15:56:48.497 |   input of IR in batch_quotes
# 15:56:51.995 |   input of PODD in batch_quotes
# 15:56:56.577 |   input of INTC in batch_quotes
# 15:57:07.454 |   input of ICE in batch_quotes
# 15:57:12.208 |   input of IFF in batch_quotes
# 15:57:24.571 |   input of IP in batch_quotes
# 15:57:38.252 |   input of IPG in batch_quotes
# 15:57:48.257 |   input of INTU in batch_quotes
# 15:57:55.675 |   input of ISRG in batch_quotes
# 15:58:01.428 |   input of IVZ in batch_quotes
# 15:58:08.079 |   input of INVH in batch_quotes
# 15:58:10.156 |   input of IQV in batch_quotes
# 15:58:12.944 |   input of IRM in batch_quotes
# 15:58:18.842 |   input of JBHT in batch_quotes
# 15:58:28.131 |   input of JBL in batch_quotes
# 15:58:34.945 |   input of JKHY in batch_quotes
# 15:58:45.650 |   input of J in batch_quotes
# 15:58:57.534 |   input of JNJ in batch_quotes
# 15:59:12.837 |   input of JCI in batch_quotes
# 15:59:21.771 |   input of JPM in batch_quotes
# 15:59:32.546 |   input of JNPR in batch_quotes
# 15:59:38.639 |   input of K in batch_quotes
# 15:59:50.395 |   input of KVUE in batch_quotes
# 15:59:51.059 |   input of KDP in batch_quotes
# 15:59:54.856 |   input of KEY in batch_quotes
# 16:00:04.283 |   input of KEYS in batch_quotes
# 16:00:06.739 |   input of KMB in batch_quotes
# 16:00:16.831 |   input of KIM in batch_quotes
# 16:00:24.598 |   input of KMI in batch_quotes
# 16:00:28.731 |   input of KKR in batch_quotes
# 16:00:33.188 |   input of KLAC in batch_quotes
# 16:00:45.634 |   input of KHC in batch_quotes
# 16:00:48.160 |   input of KR in batch_quotes
# 16:01:04.215 |   input of LHX in batch_quotes
# 16:01:15.178 |   input of LH in batch_quotes
# 16:01:24.238 |   input of LRCX in batch_quotes
# 16:01:33.657 |   input of LW in batch_quotes
# 16:01:35.725 |   input of LVS in batch_quotes
# 16:01:41.192 |   input of LDOS in batch_quotes
# 16:01:45.972 |   input of LEN in batch_quotes
# 16:01:56.797 |   input of LII in batch_quotes
# 16:02:02.881 |   input of LLY in batch_quotes
# 16:02:15.549 |   input of LIN in batch_quotes
# 16:02:24.930 |   input of LYV in batch_quotes
# 16:02:29.742 |   input of LKQ in batch_quotes
# 16:02:35.047 |   input of LMT in batch_quotes
# 16:02:46.907 |   input of L in batch_quotes
# 16:02:58.246 |   input of LOW in batch_quotes
# 16:03:08.064 |   input of LULU in batch_quotes
# 16:03:12.314 |   input of LYB in batch_quotes
# 16:03:15.813 |   input of MTB in batch_quotes
# 16:03:25.994 |   input of MPC in batch_quotes
# 16:03:29.099 |   input of MKTX in batch_quotes
# 16:03:33.558 |   input of MAR in batch_quotes
# 16:03:39.393 |   input of MMC in batch_quotes
# 16:03:49.893 |   input of MLM in batch_quotes
# 16:03:55.982 |   input of MAS in batch_quotes
# 16:04:04.436 |   input of MA in batch_quotes
# 16:04:08.181 |   input of MTCH in batch_quotes
# 16:04:14.233 |   input of MKC in batch_quotes
# 16:04:23.836 |   input of MCD in batch_quotes
# 16:04:34.510 |   input of MCK in batch_quotes
# 16:04:40.419 |   input of MDT in batch_quotes
# 16:04:50.385 |   input of MRK in batch_quotes
# 16:05:02.551 |   input of META in batch_quotes
# 16:05:05.237 |   input of MET in batch_quotes
# 16:05:10.538 |   input of MTD in batch_quotes
# 16:05:16.195 |   input of MGM in batch_quotes
# 16:05:24.026 |   input of MCHP in batch_quotes
# 16:05:30.476 |   input of MU in batch_quotes
# 16:05:38.540 |   input of MSFT in batch_quotes
# 16:05:46.823 |   input of MAA in batch_quotes
# 16:05:53.604 |   input of MRNA in batch_quotes
# 16:05:55.051 |   input of MHK in batch_quotes
# 16:06:01.798 |   input of MOH in batch_quotes
# 16:06:06.469 |   input of TAP in batch_quotes
# 16:06:17.125 |   input of MDLZ in batch_quotes
# 16:06:22.277 |   input of MPWR in batch_quotes
# 16:06:26.537 |   input of MNST in batch_quotes
# 16:06:35.139 |   input of MCO in batch_quotes
# 16:06:42.483 |   input of MS in batch_quotes
# 16:06:50.447 |   input of MOS in batch_quotes
# 16:07:00.346 |   input of MSI in batch_quotes
# 16:07:16.569 |   input of MSCI in batch_quotes
# 16:07:21.061 |   input of NDAQ in batch_quotes
# 16:07:28.062 |   input of NTAP in batch_quotes
# 16:07:36.407 |   input of NFLX in batch_quotes
# 16:07:41.772 |   input of NEM in batch_quotes
# 16:07:54.017 |   input of NWSA in batch_quotes
# 16:07:57.744 |   input of NWS in batch_quotes
# 16:08:01.690 |   input of NEE in batch_quotes
# 16:08:15.724 |   input of NKE in batch_quotes
# 16:08:30.493 |   input of NI in batch_quotes
# 16:08:48.081 |   input of NDSN in batch_quotes
# 16:09:01.508 |   input of NSC in batch_quotes
# 16:09:15.829 |   input of NTRS in batch_quotes
# 16:09:29.017 |   input of NOC in batch_quotes
# 16:09:42.420 |   input of NCLH in batch_quotes
# 16:09:46.222 |   input of NRG in batch_quotes
# 16:09:52.711 |   input of NUE in batch_quotes
# 16:10:07.000 |   input of NVDA in batch_quotes
# 16:10:14.134 |   input of NVR in batch_quotes
# 16:10:24.274 |   input of NXPI in batch_quotes
# 16:10:28.633 |   input of ORLY in batch_quotes
# 16:10:35.420 |   input of OXY in batch_quotes
# 16:10:45.456 |   input of ODFL in batch_quotes
# 16:10:53.339 |   input of OMC in batch_quotes
# 16:11:05.094 |   input of ON in batch_quotes
# 16:11:13.118 |   input of OKE in batch_quotes
# 16:11:24.347 |   input of ORCL in batch_quotes
# 16:11:34.300 |   input of OTIS in batch_quotes
# 16:11:36.271 |   input of PCAR in batch_quotes
# 16:11:47.828 |   input of PKG in batch_quotes
# 16:11:54.208 |   input of PLTR in batch_quotes
# 16:11:54.242 |   input of PANW in batch_quotes
# 16:11:57.662 |   input of PARA in batch_quotes
# 16:12:03.397 |   input of PH in batch_quotes
# 16:12:17.102 |   input of PAYX in batch_quotes
# 16:12:30.388 |   input of PAYC in batch_quotes
# 16:12:33.381 |   input of PYPL in batch_quotes
# 16:12:36.140 |   input of PNR in batch_quotes
# 16:12:49.210 |   input of PEP in batch_quotes
# 16:13:00.866 |   input of PFE in batch_quotes
# 16:13:13.247 |   input of PCG in batch_quotes
# 16:13:25.512 |   input of PM in batch_quotes
# 16:13:29.001 |   input of PSX in batch_quotes
# 16:13:32.096 |   input of PNW in batch_quotes
# 16:13:46.113 |   input of PNC in batch_quotes
# 16:13:58.461 |   input of POOL in batch_quotes
# 16:14:05.753 |   input of PPG in batch_quotes
# 16:14:19.764 |   input of PPL in batch_quotes
# 16:14:33.789 |   input of PFG in batch_quotes
# 16:14:40.057 |   input of PG in batch_quotes
# 16:14:58.151 |   input of PGR in batch_quotes
# 16:15:10.318 |   input of PLD in batch_quotes
# 16:15:18.019 |   input of PRU in batch_quotes
# 16:15:24.581 |   input of PEG in batch_quotes
# 16:15:35.792 |   input of PTC in batch_quotes
# 16:15:44.698 |   input of PSA in batch_quotes
# 16:15:55.706 |   input of PHM in batch_quotes
# 16:16:05.887 |   input of PWR in batch_quotes
# 16:16:12.471 |   input of QCOM in batch_quotes
# 16:16:20.349 |   input of DGX in batch_quotes
# 16:16:27.909 |   input of RL in batch_quotes
# 16:16:34.403 |   input of RJF in batch_quotes
# 16:16:44.628 |   input of RTX in batch_quotes
# 16:16:59.410 |   input of O in batch_quotes
# 16:17:06.610 |   input of REG in batch_quotes
# 16:17:14.164 |   input of REGN in batch_quotes
# 16:17:21.736 |   input of RF in batch_quotes
# 16:17:31.281 |   input of RSG in batch_quotes
# 16:17:36.982 |   input of RMD in batch_quotes
# 16:17:43.863 |   input of RVTY in batch_quotes
# 16:17:54.944 |   input of ROK in batch_quotes
# 16:18:03.642 |   input of ROL in batch_quotes
# 16:18:13.120 |   input of ROP in batch_quotes
# 16:18:20.197 |   input of ROST in batch_quotes
# 16:18:28.302 |   input of RCL in batch_quotes
# 16:18:34.616 |   input of SPGI in batch_quotes
# 16:18:45.882 |   input of CRM in batch_quotes
# 16:18:50.945 |   input of SBAC in batch_quotes
# 16:18:57.861 |   input of SLB in batch_quotes
# 16:19:06.495 |   input of STX in batch_quotes
# 16:19:11.010 |   input of SRE in batch_quotes
# 16:19:17.255 |   input of NOW in batch_quotes
# 16:19:20.089 |   input of SHW in batch_quotes
# 16:19:29.257 |   input of SPG in batch_quotes
# 16:19:36.345 |   input of SWKS in batch_quotes
# 16:19:45.656 |   input of SJM in batch_quotes
# 16:19:52.411 |   input of SW in batch_quotes
# 16:19:52.754 |   input of SNA in batch_quotes
# 16:20:03.377 |   input of SOLV in batch_quotes
# 16:20:03.798 |   input of SO in batch_quotes
# 16:20:13.247 |   input of LUV in batch_quotes
# 16:20:24.005 |   input of SWK in batch_quotes
# 16:20:36.544 |   input of SBUX in batch_quotes
# 16:20:46.420 |   input of STT in batch_quotes
# 16:20:58.950 |   input of STLD in batch_quotes
# 16:21:05.145 |   input of STE in batch_quotes
# 16:21:12.696 |   input of SYK in batch_quotes
# 16:21:22.663 |   input of SMCI in batch_quotes
# 16:21:26.585 |   input of SYF in batch_quotes
# 16:21:28.961 |   input of SNPS in batch_quotes
# 16:21:35.572 |   input of SYY in batch_quotes
# 16:21:47.674 |   input of TMUS in batch_quotes
# 16:21:52.488 |   input of TROW in batch_quotes
# 16:21:59.961 |   input of TTWO in batch_quotes
# 16:22:05.415 |   input of TPR in batch_quotes
# 16:22:10.440 |   input of TRGP in batch_quotes
# 16:22:10.479 |   input of TGT in batch_quotes
# 16:22:21.301 |   input of TEL in batch_quotes
# 16:22:25.599 |   input of TDY in batch_quotes
# 16:22:31.485 |   input of TER in batch_quotes
# 16:22:43.334 |   input of TSLA in batch_quotes
# 16:22:47.018 |   input of TXN in batch_quotes
# 16:23:00.989 |   input of TPL in batch_quotes
# 16:23:11.697 |   input of TXT in batch_quotes
# 16:23:23.778 |   input of TMO in batch_quotes
# 16:23:34.985 |   input of TJX in batch_quotes
# 16:23:44.572 |   input of TKO in batch_quotes
# 16:23:51.054 |   input of TSCO in batch_quotes
# 16:24:00.401 |   input of TT in batch_quotes
# 16:24:13.688 |   input of TDG in batch_quotes
# 16:24:19.257 |   input of TRV in batch_quotes
# 16:24:32.648 |   input of TRMB in batch_quotes
# 16:24:41.464 |   input of TFC in batch_quotes
# 16:24:52.269 |   input of TYL in batch_quotes
# 16:25:03.983 |   input of TSN in batch_quotes
# 16:25:15.044 |   input of USB in batch_quotes
# 16:25:28.073 |   input of UBER in batch_quotes
# 16:25:29.706 |   input of UDR in batch_quotes
# 16:25:40.298 |   input of ULTA in batch_quotes
# 16:25:45.387 |   input of UNP in batch_quotes
# 16:25:58.154 |   input of UAL in batch_quotes
# 16:25:58.213 |   input of UPS in batch_quotes
# 16:26:04.951 |   input of URI in batch_quotes
# 16:26:12.123 |   input of UNH in batch_quotes
# 16:26:22.525 |   input of UHS in batch_quotes
# 16:26:33.780 |   input of VLO in batch_quotes
# 16:26:44.829 |   input of VTR in batch_quotes
# 16:26:44.881 |   input of VLTO in batch_quotes
# 16:26:45.524 |   input of VRSN in batch_quotes
# 16:26:53.052 |   input of VRSK in batch_quotes
# 16:26:57.319 |   input of VZ in batch_quotes
# 16:27:08.482 |   input of VRTX in batch_quotes
# 16:27:18.837 |   input of VTRS in batch_quotes
# 16:27:31.360 |   input of VICI in batch_quotes
# 16:27:33.080 |   input of V in batch_quotes
# 16:27:36.938 |   input of VST in batch_quotes
# 16:27:36.978 |   input of VMC in batch_quotes
# 16:27:51.549 |   input of WRB in batch_quotes
# 16:28:05.440 |   input of GWW in batch_quotes
# 16:28:18.151 |   input of WAB in batch_quotes
# 16:28:25.419 |   input of WBA in batch_quotes
# 16:28:38.124 |   input of WMT in batch_quotes
# 16:28:56.477 |   input of DIS in batch_quotes
# 16:29:18.574 |   input of WBD in batch_quotes
# 16:29:24.257 |   input of WM in batch_quotes
# 16:29:34.352 |   input of WAT in batch_quotes
# 16:29:42.729 |   input of WEC in batch_quotes
# 16:29:55.474 |   input of WFC in batch_quotes
# 16:30:10.819 |   input of WELL in batch_quotes
# 16:30:21.780 |   input of WST in batch_quotes
# 16:30:32.466 |   input of WDC in batch_quotes
# 16:30:42.777 |   input of WY in batch_quotes
# 16:30:53.671 |   input of WSM in batch_quotes
# 16:31:03.062 |   input of WMB in batch_quotes
# 16:31:14.565 |   input of WTW in batch_quotes
# 16:31:20.930 |   input of WDAY in batch_quotes
# 16:31:23.781 |   input of WYNN in batch_quotes
# 16:31:29.840 |   input of XEL in batch_quotes
# 16:31:42.474 |   input of XYL in batch_quotes
# 16:31:46.033 |   input of YUM in batch_quotes
# 16:31:52.822 |   input of ZBRA in batch_quotes
# 16:32:02.031 |   input of ZBH in batch_quotes
# 16:32:08.172 |   input of ZTS in batch_quotes
# rm: /Users/eartigau/bydoux_data//quotes/snp500_all_*.pkl: No such file or directory
# 16:32:28.176 |  MMM, sector Industrials
# 16:32:28.450 |  AOS, sector Industrials
# 16:32:28.699 |  ABT, sector Healthcare
# 16:32:28.985 |  ABBV, sector Healthcare
# 16:32:29.950 |  ACN, sector Technology
# 16:32:30.282 |  ADBE, sector Technology
# 16:32:30.552 |  AMD, sector Technology
# 16:32:30.812 |  AES, sector Utilities
# 16:32:31.144 |  AFL, sector Financial Services
# 16:32:31.473 |  A, sector Healthcare
# 16:32:31.738 |  APD, sector Basic Materials
# 16:32:32.887 |  ABNB, sector Consumer Cyclical
# 16:32:33.161 |  AKAM, sector Technology
# 16:32:33.447 |  ALB, sector Basic Materials
# 16:32:33.721 |  ARE, sector Real Estate
# 16:32:33.992 |  ALGN, sector Healthcare
# 16:32:34.250 |  ALLE, sector Industrials
# 16:32:34.523 |  LNT, sector Utilities
# 16:32:34.814 |  ALL, sector Financial Services
# 16:32:35.146 |  GOOGL, sector Communication Services
# 16:32:35.440 |  GOOG, sector Communication Services
# 16:32:35.673 |  MO, sector Consumer Defensive
# 16:32:35.949 |  AMZN, sector Consumer Cyclical
# 16:32:36.228 |  AMCR, sector Consumer Cyclical
# 16:32:36.513 |  AEE, sector Utilities
# 16:32:36.760 |  AEP, sector Utilities
# 16:32:37.082 |  AXP, sector Financial Services
# 16:32:37.348 |  AIG, sector Financial Services
# 16:32:37.610 |  AMT, sector Real Estate
# 16:32:37.884 |  AWK, sector Utilities
# 16:32:38.639 |  AMP, sector Financial Services
# 16:32:39.331 |  AME, sector Industrials
# 16:32:41.097 |  AMGN, sector Healthcare
# 16:32:41.749 |  APH, sector Technology
# 16:32:42.095 |  ADI, sector Technology
# 16:32:42.586 |  ANSS, sector Technology
# 16:32:42.849 |  AON, sector Financial Services
# 16:32:43.120 |  APA, sector Energy
# 16:32:43.360 |  APO, sector Financial Services
# 16:36:46.315 |  HWM	gain/45 days : 1.00 	 gain/year : 1.00 	 slope : 1.01 	 sigma : 0.06 	 qual : 17.55
# 16:36:46.316 |  Sector : Industrials
# 16:36:46.316 |  SMCI	gain/45 days : 1.00 	 gain/year : 1.00 	 slope : 0.99 	 sigma : 0.14 	 qual : 7.15
# 16:36:46.317 |  Sector : Technology
# 16:36:46.317 |  DG	gain/45 days : 1.00 	 gain/year : 1.00 	 slope : 0.94 	 sigma : 0.06 	 qual : 14.66
# 16:36:46.318 |  Sector : Consumer Defensive
# 16:36:46.319 |  GE	gain/45 days : 1.00 	 gain/year : 1.00 	 slope : 0.91 	 sigma : 0.06 	 qual : 15.70
# 16:36:46.319 |  Sector : Industrials
# 16:36:46.320 |  PM	gain/45 days : 1.00 	 gain/year : 1.00 	 slope : 0.87 	 sigma : 0.04 	 qual : 19.88
# 16:36:46.320 |  Sector : Consumer Defensive
# 16:36:46.321 |  MOS	gain/45 days : 1.00 	 gain/year : 1.00 	 slope : 0.81 	 sigma : 0.07 	 qual : 10.88
# 16:36:46.321 |  Sector : Basic Materials
# /var/folders/cy/vv8rw3d12f31t1wpxpbdgmtm0000gp/T/ipykernel_92891/2339900810.py:266: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(t_year_plot, growth_nothing, 'r-')
# /var/folders/cy/vv8rw3d12f31t1wpxpbdgmtm0000gp/T/ipykernel_92891/2339900810.py:267: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(t_year_plot, growth_strategy, 'g-')
# /var/folders/cy/vv8rw3d12f31t1wpxpbdgmtm0000gp/T/ipykernel_92891/2339900810.py:339: DeprecationWarning: `cumproduct` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `cumprod` instead.
#   simu_sp500(nkeeps=[8], timesteps=[45], lookback_scales=[5], method='slope', injection=30000, nyears=20)
# /var/folders/cy/vv8rw3d12f31t1wpxpbdgmtm0000gp/T/ipykernel_92891/2339900810.py:294: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(t_year_plot,np.log(np.cumproduct(growth_strategy)))
# /var/folders/cy/vv8rw3d12f31t1wpxpbdgmtm0000gp/T/ipykernel_92891/2339900810.py:295: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(t_year_plot,np.log(np.cumproduct(growth_nothing)))
# 16:36:47.953 |  Mean yearly growth doing nothing : 1.17, rms : 0.15
# 16:36:47.954 |  Mean yearly growth with strategy : 1.33, rms : 0.23
# 16:36:48.801 |  Fraction 0.71 of 45 days with positive growth [116/163] -- strategy
# 16:36:48.803 |  Fraction 0.72 of 45 days with positive growth [118/163] -- nothing
# 16:36:48.804 |  Fraction 0.86 of yearly with positive growth [18/21] -- strategy
# 16:36:48.805 |  Fraction 0.76 of yearly with positive growth [16/21] -- nothing
