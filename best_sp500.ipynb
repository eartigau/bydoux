# %%
import bydoux_tools as bt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table
import os
from astropy.time import Time
#import datetime

import bydoux_tools as bt
from bydoux_tools import printc
# get today's date
import datetime
# import ius
from scipy.interpolate import UnivariateSpline as ius
from wpca import PCA
from scipy.special import erf

# %%
def simu_sp500(nkeeps=[10], timesteps=[45], lookback_scales=[7], method='slope', injection=30000, nyears=20, doplot=True):

    tickers0 = bt.get_snp500()
    tickers = np.array(tickers0)

    lookbacks = np.array(timesteps) * np.array(lookback_scales)


    today = bt.today()

    tbl = Table()
    tbl['nkeeps'] = nkeeps
    tbl['timestep'] = timesteps
    tbl['lookback_scale'] = lookback_scales
    tbl['method'] = method
    tbl['mean_growth_nothing'] = np.nan
    tbl['mean_growth_strategy'] = np.nan
    tbl['rms_nothing'] = np.nan
    tbl['rms_strategy'] = np.nan
    all_gains_keep = []


    for nth_simu in range(len(nkeeps)):
        all_sp500 = bt.batch_quotes('S&P500', force=False)

        nkeep = nkeeps[nth_simu]
        timestep = timesteps[nth_simu]
        lookback_scale = lookback_scales[nth_simu]
        lookback = lookbacks[nth_simu]

        scenario_name = f'{timestep}days_{lookback}days_{nyears}years_{nkeep}stocks_{method}'

        t_decision = Time(datetime.datetime.now()).mjd - np.arange(0, 365 * nyears, timestep)

        tmax = all_sp500[tickers[0]]['mjd'][-1]


        growth_nothing = np.zeros(len(t_decision))
        growth_strategy = np.zeros(len(t_decision))

        t_decision = t_decision[np.argsort(t_decision)]


        sectors_ini = []
        # get all sectors:
        for ticker in tickers:
            try:
                info = bt.get_info(ticker)
                sect = info['sector']
                printc(f'{ticker}, sector {sect}')
                sectors_ini.append(info['sector'])
            except:
                sectors_ini.append('Unknown')

        sectors_ini = np.array(sectors_ini)

        dict_gains = {}
        for imc in range(len(t_decision)):
            kept_keys = []
            gains = []
            slopes = []
            sigmas = []
            sectors = []

            tickers = np.array(tickers0)

            for iticker in range(len(tickers)):
                ticker = tickers[iticker]

                if ticker not in all_sp500.keys():
                    continue

                tbl1 = dict(all_sp500[ticker])
                if len(tbl1['date'])<100:
                    continue


                t1 = t_decision[imc] - lookback#[nth_simu]
                t2 = t_decision[imc]+timestep#[nth_simu]

                time_valid = (tbl1['mjd']>t1) & (tbl1['mjd']<t2)
                if np.sum(time_valid)<0.5*lookback:
                    continue

                for key_tbl in tbl1.keys():
                    tbl1[key_tbl] = tbl1[key_tbl][time_valid]

                dt = np.max(tbl1['mjd']) - tbl1['mjd']

                keep_for_fit = tbl1['mjd'] < t_decision[imc]
                keep_for_fit2 = (tbl1['mjd'] < t_decision[imc]) * (tbl1['mjd'] > (t_decision[imc] - timestep))
                
                if np.sum(keep_for_fit)<0.5*lookback:
                    continue

                if method == 'slope':
                    # error increases with lookback time
                    #tt = tbl1['mjd'][keep_for_fit] #/ 365.25
                    #tt = np.abs(tt - np.max(tt))
                    #w=1/(tt+lookback)
                    #w/=w[-1]


                    
                    #tt+=1
                    #sig = np.nanstd(tbl1['log_close'][keep_for_fit]) * np.sqrt(lookback_scale)
                    #fit = np.polyfit(tbl1['mjd'][keep_for_fit] / 365.25, tbl1['log_close'][keep_for_fit],1, w=w)
                    fit = np.polyfit(tbl1['mjd'][keep_for_fit] / 365.25, tbl1['log_close'][keep_for_fit],1)
                    fit2 = np.polyfit(tbl1['mjd'][keep_for_fit2] / 365.25, tbl1['log_close'][keep_for_fit2],1)
                    rms = (tbl1['log_close'][keep_for_fit] - np.polyval(fit, tbl1['mjd'][keep_for_fit] / 365.25))

                    sigma = np.nanmean(np.abs(rms))

                    slopes.append(fit[0]+fit2[0]*.2)
                    sigmas.append(sigma)

                elif method == 'mean':
                    slopes.append(tbl1['log_close'][keep_for_fit][-1] - np.nanmean(tbl1['log_close'][keep_for_fit][-1]))
                    sigmas.append(np.nanstd(tbl1['log_close'][keep_for_fit]))

                elif method == 'cheaper':
                    slopes.append( - tbl1['Close'][keep_for_fit][-1])
                    sigmas.append(np.nanstd(tbl1['log_close'][keep_for_fit]))


                last_iteration = (np.max(tbl1['mjd']) == t_decision[imc])

                if not last_iteration:
                    gain = tbl1['log_close'][-1]- tbl1['log_close'][keep_for_fit][-1]
                    gains.append(gain)
                else:
                    gains.append(np.nan)

                kept_keys.append(ticker)
                sectors.append(sectors_ini[iticker])

                outname = '/Users/eartigau/pydoux_data/quotes/' + ticker + '_' + today + '.csv'


            slopes = np.array(slopes)
            sigmas = np.array(sigmas)
            gains = np.array(gains)
            keys = np.array(kept_keys)
            sectors = np.array(sectors)


            # we keep only the best nkeep stocks
            ord = np.argsort(slopes)[::-1]

            # we reorder the arrays according to the order vector
            gains_keep = gains[ord]#[0:nkeep]
            slopes_keep = slopes[ord]#[0:nkeep]
            sigmas_keep = sigmas[ord]#[0:nkeep]
            keys_keep = keys[ord]#[0:nkeep]
            sectors_keep = sectors[ord]#[0:nkeep]

            if True:
                keep = np.array([False]*len(gains_keep))

                usector =  np.unique(sectors_keep)
                for sector in usector:
                    mask = sectors_keep == sector
                    if np.sum(mask)<3:
                        continue

                    tmp = keep[mask]
                    nmax = nkeep//4
                    tmp[0:nmax] = True
                    keep[mask] = tmp

                gains_keep = gains_keep[keep]
                slopes_keep = slopes_keep[keep]
                sigmas_keep = sigmas_keep[keep]
                keys_keep = keys_keep[keep]
                sectors_keep = sectors_keep[keep]

            prob_gain = np.zeros(len(gains_keep))+0.04
            for i in range(len(gains_keep)):
                if keys_keep[i] in dict_gains.keys():
                    prob_gain[i] = np.nanmean(dict_gains[keys_keep[i]])

            ord = np.argsort(keys_keep)
            gains_keep = gains_keep[0:nkeep]
            slopes_keep = slopes_keep[0:nkeep]
            sigmas_keep = sigmas_keep[0:nkeep]
            keys_keep = keys_keep[0:nkeep]
            sectors_keep = sectors_keep[0:nkeep]
            prob_gain = prob_gain[0:nkeep]

            all_gains_keep.append(gains_keep)

            #ww = erf((prob_gain-np.mean(prob_gain))/0.05)*0.5+0.5
            #ww[ww<0] = 0
            ##ww[ww>np.nanmedian(ww)] = 2*np.nanmedian(ww)
            #ww/=np.mean(ww)

            for key in keys_keep:
                if key not in dict_gains.keys():
                    dict_gains[key] = []
                dict_gains[key].append(gains_keep[np.where(keys_keep == key)[0][0]])
            

            printc('~'*80)
            #os.system('clear')

            t_year = (t_decision[imc] - Time('2000-01-01').mjd) / 365.25 + 2000

            time_str= Time(t_decision[imc],format='mjd').iso.split(' ')[0]
            printc(f'Simulation {nth_simu+1}/{len(nkeeps)}')
            print(f'Date : {time_str}')
            printc(f'Year : {t_year:.2f}')
            gain1 = np.nanmean(np.exp(gains)) #** (365 / dt2)
            printc(f'gain/{timestep:.0f} days doing nothing, {gain1:.2f}')

            ww = np.ones_like(gains_keep)
            ww/=np.mean(ww)
            gain2 = np.nanmean(np.exp(gains_keep)*ww) #** (365 / dt2)
            printc(f'gain/{timestep:.0f} days with strategy, {gain2:.2f}')


            growth_nothing[imc] = gain1
            growth_strategy[imc] = gain2


            for i in range(len(gains_keep)):
                ptxt = keys_keep[i],np.exp(gains_keep[i]), np.exp(gains_keep[i] * (365 / timestep)), slopes_keep[i], sigmas_keep[i], \
                    slopes_keep[i] / sigmas_keep[i]
                strtxt = f'{ptxt[0]}\tgain/{timestep} days : {ptxt[1]:.2f} \t gain/year : {ptxt[2]:.2f} \t slope : {ptxt[3]:.2f} ' \
                        f'\t ' \
                        f'sigma :' \
                        f' {ptxt[4]:.2f} \t qual : {ptxt[5]:.2f}'
                printc(strtxt)
                printc(f'Sector : {sectors_keep[i]}')

        all_gains_histo = np.exp(np.array(all_gains_keep).ravel())
        plt.hist(all_gains_histo, bins=30, histtype='step', range=[0.6,1.8], fill=True)
        plt.xlabel('Growth in {} days'.format(timestep))
        plt.ylabel('Number of stocks')
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.show()

        if doplot:
            vv = np.array([growth_nothing,growth_strategy])
            vv = vv.ravel()
            vv = vv[np.isfinite(vv)]
            p1,p99 = np.percentile(vv,[1,99])
            prange = [p1,p99]
            width = p99-p1
            prange[0]-=0.1*width
            prange[1]+=0.1*width

            plt.hist(growth_nothing, bins=30, histtype='step', color='r', label='Nothing', range=prange, fill=True,
                    alpha =0.5)
            plt.hist(growth_strategy, bins=30, histtype='step', color='g', label='Strategy', alpha = 0.5, fill=True, range=prange)
            plt.legend()
            plt.show()


        mean_growth_nothing = np.nanprod(growth_nothing)**(1/nyears)
        mean_growth_strategy = np.nanprod(growth_strategy)**(1/nyears)

        t_year = (t_decision - Time('2000-01-01').mjd)/365.25+2000

        t_year_plot = t_decision - Time('1970-01-01').mjd
        if doplot:
            plt.plot_date(t_year_plot, growth_nothing, 'r-')
            plt.plot_date(t_year_plot, growth_strategy, 'g-')
            plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
            plt.show()

        fit_nothing = np.polyfit(t_year,np.log(np.cumproduct(growth_nothing)),1)
        rms_nothing = np.nanstd(np.log(np.cumproduct(growth_nothing)) - np.polyval(fit_nothing,t_year))

        fit_strategy = np.polyfit(t_year,np.log(np.cumproduct(growth_strategy)),1)
        rms_strategy = np.nanstd(np.log(np.cumproduct(growth_strategy)) - np.polyval(fit_strategy,t_year))

        printc(f'Mean yearly growth doing nothing : {mean_growth_nothing:.2f}, rms : {rms_nothing:.2f}')
        printc(f'Mean yearly growth with strategy : {mean_growth_strategy:.2f}, rms : {rms_strategy:.2f}')

        tbl['mean_growth_nothing'][nth_simu] = mean_growth_nothing
        tbl['mean_growth_strategy'][nth_simu] = mean_growth_strategy
        tbl['rms_nothing'][nth_simu] = rms_nothing
        tbl['rms_strategy'][nth_simu] = rms_strategy

        uyear = np.unique(t_year.astype(int))
        year_mean_nothing = np.zeros(len(uyear))
        year_mean_strategy = np.zeros(len(uyear))
        for i, year in enumerate(uyear):
            mask = t_year.astype(int) == year
            year_mean_nothing[i] = np.prod(growth_nothing[mask])
            year_mean_strategy[i] = np.prod(growth_strategy[mask])

        if doplot:
            plt.plot_date(t_year_plot,np.log(np.cumproduct(growth_strategy)))
            plt.plot_date(t_year_plot,np.log(np.cumproduct(growth_nothing)))
            plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
            plt.show()


            plt.step(uyear,year_mean_nothing,'r',label='Nothing')
            plt.step(uyear,year_mean_strategy,'g',label='Strategy')
            plt.legend()
            plt.show()

            year_mean_strategy[year_mean_strategy<0.5] = 0.5
            year_mean_nothing[year_mean_nothing<0.5] = 0.5
            year_mean_nothing[year_mean_nothing>2] = 2
            year_mean_strategy[year_mean_strategy>2] = 2
            plt.hist(year_mean_strategy, bins=10, histtype='step', color='g', label='Strategy', range=[0.4,2], fill=True,
                    alpha =0.5)
            plt.hist(year_mean_nothing, bins=10, histtype='step', color='r', label='Nothing', range=[0.4,2], fill=True,
                    alpha =0.5)
            plt.legend()
            plt.show()


        printc(f'Fraction {np.sum(growth_strategy>1)/len(growth_strategy):.2f} of {timestep} days with positive growth [{np.sum(growth_strategy>1)}/{len(growth_strategy)}] -- '
                f'strategy')
        printc(f'Fraction {np.sum(growth_nothing>1)/len(growth_nothing):.2f} of {timestep} days with positive growth [{np.sum(growth_nothing>1)}/{len(growth_nothing)}] -- nothing')

        printc(f'Fraction {np.sum(year_mean_strategy>1)/len(year_mean_strategy):.2f} of yearly with positive growth [{np.sum(year_mean_strategy>1)}/{len(year_mean_strategy)}] -- '
            f'strategy')
        printc(f'Fraction {np.sum(year_mean_nothing>1)/len(year_mean_nothing):.2f} of yearly with positive growth [{np.sum(year_mean_nothing>1)}/{len(year_mean_nothing)}] -- nothing')
"""
nkeeps = [10]
timesteps = [45]
lookback_scales = [5]
method = 'slope'
injection = 30000
nyears = 15

"""




if __name__ == "__main__":
    #simu_sp500(nkeeps=[10], timesteps=[45], lookback_scales=[5], method='slope', injection=30000, nyears=25)    
    simu_sp500(nkeeps=[8], timesteps=[45], lookback_scales=[5], method='slope', injection=30000, nyears=20)
# Out:
# 17:09:01.746 |   input of MMM in batch_quotes
# 17:09:11.048 |   input of AOS in batch_quotes
# 17:09:17.153 |   input of ABT in batch_quotes
# 17:09:23.665 |   input of ABBV in batch_quotes
# 17:09:26.253 |   input of ACN in batch_quotes
# 17:09:29.974 |   input of ADBE in batch_quotes
# 17:09:35.530 |   input of AMD in batch_quotes
# 17:09:41.615 |   input of AES in batch_quotes
# 17:09:47.459 |   input of AFL in batch_quotes
# 17:09:53.833 |   input of A in batch_quotes
# 17:09:57.569 |   input of APD in batch_quotes
# 17:10:04.049 |   input of ABNB in batch_quotes
# 17:10:05.123 |   input of AKAM in batch_quotes
# 17:10:08.911 |   input of ALB in batch_quotes
# 17:10:13.197 |   input of ARE in batch_quotes
# 17:10:17.803 |   input of ALGN in batch_quotes
# 17:10:27.171 |   input of ALLE in batch_quotes
# 17:10:29.247 |   input of LNT in batch_quotes
# 17:10:37.005 |   input of ALL in batch_quotes
# 17:10:41.870 |   input of GOOGL in batch_quotes
# 17:10:45.067 |   input of GOOG in batch_quotes
# 17:10:48.884 |   input of MO in batch_quotes
# 17:10:59.017 |   input of AMZN in batch_quotes
# 17:11:03.616 |   input of AMCR in batch_quotes
# 17:11:06.567 |   input of AEE in batch_quotes
# 17:11:10.559 |   input of AEP in batch_quotes
# 17:11:19.016 |   input of AXP in batch_quotes
# 17:11:25.975 |   input of AIG in batch_quotes
# 17:11:33.050 |   input of AMT in batch_quotes
# 17:11:36.957 |   input of AWK in batch_quotes
# 17:11:40.048 |   input of AMP in batch_quotes
# 17:11:43.054 |   input of AME in batch_quotes
# 17:11:49.092 |   input of AMGN in batch_quotes
# 17:11:55.007 |   input of APH in batch_quotes
# 17:11:59.979 |   input of ADI in batch_quotes
# 17:12:06.595 |   input of AON in batch_quotes
# 17:12:12.842 |   input of APA in batch_quotes
# 17:12:21.279 |   input of APO in batch_quotes
# 17:12:24.365 |   input of AAPL in batch_quotes
# 17:12:30.731 |   input of AMAT in batch_quotes
# 17:12:37.075 |   input of APTV in batch_quotes
# 17:12:39.340 |   input of ACGL in batch_quotes
# 17:12:43.700 |   input of ADM in batch_quotes
# 17:12:50.016 |   input of ANET in batch_quotes
# 17:12:51.990 |   input of AJG in batch_quotes
# 17:12:57.719 |   input of AIZ in batch_quotes
# 17:13:00.939 |   input of T in batch_quotes
# 17:13:06.728 |   input of ATO in batch_quotes
# 17:13:12.527 |   input of ADSK in batch_quotes
# 17:13:18.676 |   input of ADP in batch_quotes
# 17:13:24.929 |   input of AZO in batch_quotes
# 17:13:29.880 |   input of AVB in batch_quotes
# 17:13:34.406 |   input of AVY in batch_quotes
# 17:13:41.699 |   input of AXON in batch_quotes
# 17:13:42.096 |   input of BKR in batch_quotes
# 17:13:47.745 |   input of BALL in batch_quotes
# 17:13:55.350 |   input of BAC in batch_quotes
# 17:14:02.808 |   input of BAX in batch_quotes
# 17:14:08.901 |   input of BDX in batch_quotes
# 17:14:16.096 |   input of BRK.B in batch_quotes
# 17:14:16.097 |  failed for BRK.B
# 17:14:16.098 |   input of BBY in batch_quotes
# 17:14:21.612 |   input of TECH in batch_quotes
# 17:14:26.974 |   input of BIIB in batch_quotes
# 17:14:31.822 |   input of BLK in batch_quotes
# 17:14:35.583 |   input of BX in batch_quotes
# 17:14:38.335 |   input of XYZ in batch_quotes
# 17:14:40.173 |   input of BK in batch_quotes
# 17:14:47.120 |   input of BA in batch_quotes
# 17:14:55.495 |   input of BKNG in batch_quotes
# 17:14:59.301 |   input of BSX in batch_quotes
# 17:15:03.959 |   input of BMY in batch_quotes
# 17:15:10.995 |   input of AVGO in batch_quotes
# 17:15:13.518 |   input of BR in batch_quotes
# 17:15:16.400 |   input of BRO in batch_quotes
# 17:15:23.150 |   input of BF.B in batch_quotes
# 17:15:23.151 |  failed for BF.B
# 17:15:23.152 |   input of BLDR in batch_quotes
# 17:15:26.873 |   input of BG in batch_quotes
# 17:15:30.774 |   input of BXP in batch_quotes
# 17:15:35.106 |   input of CHRW in batch_quotes
# 17:15:35.465 |   input of CDNS in batch_quotes
# 17:15:41.828 |   input of CZR in batch_quotes
# 17:15:43.734 |  Added CZR to /Users/eartigau/bydoux/summary_Equity.csv
# 17:15:43.734 |   input of CPT in batch_quotes
# 17:15:48.339 |   input of CPB in batch_quotes
# 17:15:55.439 |   input of COF in batch_quotes
# 17:16:00.795 |   input of CAH in batch_quotes
# 17:16:07.131 |   input of KMX in batch_quotes
# 17:16:11.100 |   input of CCL in batch_quotes
# 17:16:16.642 |   input of CARR in batch_quotes
# 17:16:17.850 |   input of CAT in batch_quotes
# 17:16:26.365 |   input of CBOE in batch_quotes
# 17:16:28.892 |   input of CBRE in batch_quotes
# 17:16:32.154 |   input of CDW in batch_quotes
# 17:16:34.238 |   input of COR in batch_quotes
# 17:16:40.446 |   input of CNC in batch_quotes
# 17:16:45.887 |   input of CNP in batch_quotes
# 17:16:54.298 |   input of CF in batch_quotes
# 17:16:57.518 |   input of CRL in batch_quotes
# 17:17:01.271 |   input of SCHW in batch_quotes
# 17:17:07.140 |   input of CHTR in batch_quotes
# 17:17:09.656 |   input of CVX in batch_quotes
# 17:17:18.208 |   input of CMG in batch_quotes
# 17:17:21.251 |   input of CB in batch_quotes
# 17:17:25.819 |   input of CHD in batch_quotes
# 17:17:32.196 |   input of CI in batch_quotes
# 17:17:38.047 |   input of CINF in batch_quotes
# 17:17:44.062 |   input of CTAS in batch_quotes
# 17:17:49.997 |   input of CSCO in batch_quotes
# 17:17:55.507 |   input of C in batch_quotes
# 17:18:02.111 |   input of CFG in batch_quotes
# 17:18:04.005 |   input of CLX in batch_quotes
# 17:18:11.064 |   input of CME in batch_quotes
# 17:18:14.395 |   input of CMS in batch_quotes
# 17:18:21.340 |   input of KO in batch_quotes
# 17:18:29.671 |   input of CTSH in batch_quotes
# 17:18:33.671 |   input of COIN in batch_quotes
# 17:18:34.732 |   input of CL in batch_quotes
# 17:18:41.675 |   input of CMCSA in batch_quotes
# 17:18:47.789 |   input of CAG in batch_quotes
# 17:18:54.282 |   input of COP in batch_quotes
# 17:19:00.553 |   input of ED in batch_quotes
# 17:19:09.103 |   input of STZ in batch_quotes
# 17:19:13.626 |   input of CEG in batch_quotes
# 17:19:14.537 |   input of COO in batch_quotes
# 17:19:20.121 |   input of CPRT in batch_quotes
# 17:19:24.468 |   input of GLW in batch_quotes
# 17:19:30.370 |   input of CPAY in batch_quotes
# 17:19:32.700 |   input of CTVA in batch_quotes
# 17:19:34.023 |   input of CSGP in batch_quotes
# 17:19:37.930 |   input of COST in batch_quotes
# 17:19:43.384 |   input of CTRA in batch_quotes
# 17:19:48.272 |   input of CRWD in batch_quotes
# 17:19:49.545 |   input of CCI in batch_quotes
# 17:19:53.371 |   input of CSX in batch_quotes
# 17:19:59.491 |   input of CMI in batch_quotes
# 17:20:06.419 |   input of CVS in batch_quotes
# 17:20:13.115 |   input of DHR in batch_quotes
# 17:20:19.133 |   input of DRI in batch_quotes
# 17:20:23.285 |   input of DDOG in batch_quotes
# 17:20:24.502 |   input of DVA in batch_quotes
# 17:20:28.561 |   input of DAY in batch_quotes
# 17:20:29.977 |   input of DECK in batch_quotes
# 17:20:38.197 |   input of DE in batch_quotes
# 17:20:45.093 |   input of DELL in batch_quotes
# 17:20:46.673 |   input of DAL in batch_quotes
# 17:20:49.492 |   input of DVN in batch_quotes
# 17:20:54.858 |   input of DXCM in batch_quotes
# 17:20:57.830 |   input of FANG in batch_quotes
# 17:21:00.096 |   input of DLR in batch_quotes
# 17:21:03.255 |   input of DG in batch_quotes
# 17:21:05.748 |   input of DLTR in batch_quotes
# 17:21:09.933 |   input of D in batch_quotes
# 17:21:16.014 |   input of DPZ in batch_quotes
# 17:21:19.133 |   input of DASH in batch_quotes
# 17:21:20.182 |   input of DOV in batch_quotes
# 17:21:26.126 |   input of DOW in batch_quotes
# 17:21:27.418 |   input of DHI in batch_quotes
# 17:21:32.062 |   input of DTE in batch_quotes
# 17:21:40.253 |   input of DUK in batch_quotes
# 17:21:46.808 |   input of DD in batch_quotes
# 17:21:53.892 |   input of EMN in batch_quotes
# 17:21:58.181 |   input of ETN in batch_quotes
# 17:22:05.423 |   input of EBAY in batch_quotes
# 17:22:09.633 |   input of ECL in batch_quotes
# 17:22:19.113 |   input of EIX in batch_quotes
# 17:22:31.376 |   input of EW in batch_quotes
# 17:22:35.604 |   input of EA in batch_quotes
# 17:22:40.921 |   input of ELV in batch_quotes
# 17:22:44.534 |   input of EMR in batch_quotes
# 17:22:52.194 |   input of ENPH in batch_quotes
# 17:22:54.577 |  Added ENPH to /Users/eartigau/bydoux/summary_Equity.csv
# 17:22:54.578 |   input of ETR in batch_quotes
# 17:23:02.266 |   input of EOG in batch_quotes
# 17:23:07.714 |   input of EPAM in batch_quotes
# 17:23:09.961 |   input of EQT in batch_quotes
# 17:23:16.451 |   input of EFX in batch_quotes
# 17:23:22.739 |   input of EQIX in batch_quotes
# 17:23:26.605 |   input of EQR in batch_quotes
# 17:23:31.274 |   input of ERIE in batch_quotes
# 17:23:36.381 |   input of ESS in batch_quotes
# 17:23:41.224 |   input of EL in batch_quotes
# 17:23:45.621 |   input of EG in batch_quotes
# 17:23:50.048 |   input of EVRG in batch_quotes
# 17:23:58.168 |   input of ES in batch_quotes
# 17:24:06.585 |   input of EXC in batch_quotes
# 17:24:14.671 |   input of EXE in batch_quotes
# 17:24:15.937 |   input of EXPE in batch_quotes
# 17:24:19.461 |   input of EXPD in batch_quotes
# 17:24:25.633 |   input of EXR in batch_quotes
# 17:24:28.996 |   input of XOM in batch_quotes
# 17:24:39.701 |   input of FFIV in batch_quotes
# 17:24:43.859 |   input of FDS in batch_quotes
# 17:24:48.333 |   input of FICO in batch_quotes
# 17:24:48.727 |   input of FAST in batch_quotes
# 17:24:54.133 |   input of FRT in batch_quotes
# 17:25:01.278 |   input of FDX in batch_quotes
# 17:25:07.892 |   input of FIS in batch_quotes
# 17:25:11.613 |   input of FITB in batch_quotes
# 17:25:18.502 |   input of FSLR in batch_quotes
# 17:25:21.564 |   input of FE in batch_quotes
# 17:25:25.703 |   input of FI in batch_quotes
# 17:25:31.322 |   input of F in batch_quotes
# 17:25:38.446 |   input of FTNT in batch_quotes
# 17:25:38.772 |   input of FTV in batch_quotes
# 17:25:40.443 |   input of FOXA in batch_quotes
# 17:25:41.760 |   input of FOX in batch_quotes
# 17:25:43.175 |   input of BEN in batch_quotes
# 17:25:49.046 |   input of FCX in batch_quotes
# 17:25:53.355 |   input of GRMN in batch_quotes
# 17:25:57.075 |   input of IT in batch_quotes
# 17:26:01.701 |   input of GE in batch_quotes
# 17:26:10.678 |   input of GEHC in batch_quotes
# 17:26:11.510 |   input of GEV in batch_quotes
# 17:26:11.856 |   input of GEN in batch_quotes
# 17:26:17.203 |   input of GNRC in batch_quotes
# 17:26:19.850 |   input of GD in batch_quotes
# 17:26:28.630 |   input of GIS in batch_quotes
# 17:26:35.649 |   input of GM in batch_quotes
# 17:26:38.730 |   input of GPC in batch_quotes
# 17:26:46.539 |   input of GILD in batch_quotes
# 17:26:53.701 |   input of GPN in batch_quotes
# 17:26:57.779 |   input of GL in batch_quotes
# 17:27:04.453 |   input of GDDY in batch_quotes
# 17:27:06.619 |   input of GS in batch_quotes
# 17:27:11.223 |   input of HAL in batch_quotes
# 17:27:20.129 |   input of HIG in batch_quotes
# 17:27:25.573 |   input of HAS in batch_quotes
# 17:27:33.177 |   input of HCA in batch_quotes
# 17:27:35.723 |   input of DOC in batch_quotes
# 17:27:42.239 |   input of HSIC in batch_quotes
# 17:27:47.059 |   input of HSY in batch_quotes
# 17:27:53.795 |   input of HPE in batch_quotes
# 17:27:55.770 |   input of HLT in batch_quotes
# 17:27:57.928 |   input of HOLX in batch_quotes
# 17:28:03.508 |   input of HD in batch_quotes
# 17:28:10.664 |   input of HON in batch_quotes
# 17:28:19.832 |   input of HRL in batch_quotes
# 17:28:26.430 |   input of HST in batch_quotes
# 17:28:32.840 |   input of HWM in batch_quotes
# 17:28:34.507 |   input of HPQ in batch_quotes
# 17:28:43.234 |   input of HUBB in batch_quotes
# 17:28:50.811 |   input of HUM in batch_quotes
# 17:28:58.598 |   input of HBAN in batch_quotes
# 17:29:07.291 |   input of HII in batch_quotes
# 17:29:10.302 |   input of IBM in batch_quotes
# 17:29:18.956 |   input of IEX in batch_quotes
# 17:29:24.135 |   input of IDXX in batch_quotes
# 17:29:29.429 |   input of ITW in batch_quotes
# 17:29:37.427 |   input of INCY in batch_quotes
# 17:29:42.275 |   input of IR in batch_quotes
# 17:29:44.515 |   input of PODD in batch_quotes
# 17:29:47.454 |   input of INTC in batch_quotes
# 17:29:54.754 |   input of IBKR in batch_quotes
# 17:29:57.740 |   input of ICE in batch_quotes
# 17:30:01.116 |   input of IFF in batch_quotes
# 17:30:09.406 |   input of IP in batch_quotes
# 17:30:19.749 |   input of IPG in batch_quotes
# 17:30:28.403 |   input of INTU in batch_quotes
# 17:30:35.667 |   input of ISRG in batch_quotes
# 17:30:40.982 |   input of IVZ in batch_quotes
# 17:30:48.640 |   input of INVH in batch_quotes
# 17:30:51.191 |   input of IQV in batch_quotes
# 17:30:53.980 |   input of IRM in batch_quotes
# 17:30:54.388 |   input of JBHT in batch_quotes
# 17:31:03.509 |   input of JBL in batch_quotes
# 17:31:09.814 |   input of JKHY in batch_quotes
# 17:31:17.594 |   input of J in batch_quotes
# 17:31:27.852 |   input of JNJ in batch_quotes
# 17:31:40.113 |   input of JCI in batch_quotes
# 17:31:47.378 |   input of JPM in batch_quotes
# 17:31:56.606 |   input of K in batch_quotes
# 17:32:07.457 |   input of KVUE in batch_quotes
# 17:32:08.533 |   input of KDP in batch_quotes
# 17:32:12.987 |   input of KEY in batch_quotes
# 17:32:20.640 |   input of KEYS in batch_quotes
# 17:32:23.153 |   input of KMB in batch_quotes
# 17:32:31.171 |   input of KIM in batch_quotes
# 17:32:39.981 |   input of KMI in batch_quotes
# 17:32:43.514 |   input of KKR in batch_quotes
# 17:32:46.435 |   input of KLAC in batch_quotes
# 17:32:53.903 |   input of KHC in batch_quotes
# 17:32:56.162 |   input of KR in batch_quotes
# 17:33:07.213 |   input of LHX in batch_quotes
# 17:33:15.693 |   input of LH in batch_quotes
# 17:33:21.877 |   input of LRCX in batch_quotes
# 17:33:28.880 |   input of LW in batch_quotes
# 17:33:30.859 |   input of LVS in batch_quotes
# 17:33:34.579 |   input of LDOS in batch_quotes
# 17:33:37.905 |   input of LEN in batch_quotes
# 17:33:46.230 |   input of LII in batch_quotes
# 17:33:51.015 |   input of LLY in batch_quotes
# 17:34:00.486 |   input of LIN in batch_quotes
# 17:34:08.321 |   input of LYV in batch_quotes
# 17:34:12.168 |   input of LKQ in batch_quotes
# 17:34:16.291 |   input of LMT in batch_quotes
# 17:34:24.581 |   input of L in batch_quotes
# 17:34:32.300 |   input of LOW in batch_quotes
# 17:34:40.106 |   input of LULU in batch_quotes
# 17:34:43.709 |   input of LYB in batch_quotes
# 17:34:46.731 |   input of MTB in batch_quotes
# 17:34:55.571 |   input of MPC in batch_quotes
# 17:34:58.591 |   input of MKTX in batch_quotes
# 17:35:02.781 |  Added MKTX to /Users/eartigau/bydoux/summary_Equity.csv
# 17:35:02.781 |   input of MAR in batch_quotes
# 17:35:07.954 |   input of MMC in batch_quotes
# 17:35:16.685 |   input of MLM in batch_quotes
# 17:35:22.168 |   input of MAS in batch_quotes
# 17:35:30.032 |   input of MA in batch_quotes
# 17:35:33.627 |   input of MTCH in batch_quotes
# 17:35:40.301 |   input of MKC in batch_quotes
# 17:35:50.215 |   input of MCD in batch_quotes
# 17:36:00.232 |   input of MCK in batch_quotes
# 17:36:06.050 |   input of MDT in batch_quotes
# 17:36:14.893 |   input of MRK in batch_quotes
# 17:36:25.647 |   input of META in batch_quotes
# 17:36:29.003 |   input of MET in batch_quotes
# 17:36:33.659 |   input of MTD in batch_quotes
# 17:36:38.653 |   input of MGM in batch_quotes
# 17:36:45.375 |   input of MCHP in batch_quotes
# 17:36:52.458 |   input of MU in batch_quotes
# 17:37:03.458 |   input of MSFT in batch_quotes
# 17:37:11.778 |   input of MAA in batch_quotes
# 17:37:17.646 |   input of MRNA in batch_quotes
# 17:37:19.959 |   input of MHK in batch_quotes
# 17:37:26.248 |   input of MOH in batch_quotes
# 17:37:30.516 |   input of TAP in batch_quotes
# 17:37:39.275 |   input of MDLZ in batch_quotes
# 17:37:43.542 |   input of MPWR in batch_quotes
# 17:37:47.218 |   input of MNST in batch_quotes
# 17:37:53.902 |   input of MCO in batch_quotes
# 17:37:59.975 |   input of MS in batch_quotes
# 17:38:06.534 |   input of MOS in batch_quotes
# 17:38:13.323 |   input of MSI in batch_quotes
# 17:38:25.854 |   input of MSCI in batch_quotes
# 17:38:29.531 |   input of NDAQ in batch_quotes
# 17:38:33.969 |   input of NTAP in batch_quotes
# 17:38:40.056 |   input of NFLX in batch_quotes
# 17:38:44.355 |   input of NEM in batch_quotes
# 17:38:53.069 |   input of NWSA in batch_quotes
# 17:38:55.837 |   input of NWS in batch_quotes
# 17:38:58.486 |   input of NEE in batch_quotes
# 17:39:07.555 |   input of NKE in batch_quotes
# 17:39:15.104 |   input of NI in batch_quotes
# 17:39:24.033 |   input of NDSN in batch_quotes
# 17:39:32.111 |   input of NSC in batch_quotes
# 17:39:39.835 |   input of NTRS in batch_quotes
# 17:39:48.778 |   input of NOC in batch_quotes
# 17:39:56.448 |   input of NCLH in batch_quotes
# 17:39:59.123 |   input of NRG in batch_quotes
# 17:40:03.189 |   input of NUE in batch_quotes
# 17:40:11.186 |   input of NVDA in batch_quotes
# 17:40:16.056 |   input of NVR in batch_quotes
# 17:40:22.958 |   input of NXPI in batch_quotes
# 17:40:25.950 |   input of ORLY in batch_quotes
# 17:40:32.679 |   input of OXY in batch_quotes
# 17:40:40.357 |   input of ODFL in batch_quotes
# 17:40:46.067 |   input of OMC in batch_quotes
# 17:40:53.443 |   input of ON in batch_quotes
# 17:40:58.477 |   input of OKE in batch_quotes
# 17:41:06.183 |   input of ORCL in batch_quotes
# 17:41:13.037 |   input of OTIS in batch_quotes
# 17:41:14.887 |   input of PCAR in batch_quotes
# 17:41:22.361 |   input of PKG in batch_quotes
# 17:41:26.624 |   input of PLTR in batch_quotes
# 17:41:26.973 |   input of PANW in batch_quotes
# 17:41:29.522 |   input of PSKY in batch_quotes
# 17:41:33.393 |   input of PH in batch_quotes
# 17:41:41.097 |   input of PAYX in batch_quotes
# 17:41:48.427 |   input of PAYC in batch_quotes
# 17:41:50.916 |   input of PYPL in batch_quotes
# 17:41:53.137 |   input of PNR in batch_quotes
# 17:42:03.362 |   input of PEP in batch_quotes
# 17:42:13.251 |   input of PFE in batch_quotes
# 17:42:23.074 |   input of PCG in batch_quotes
# 17:42:33.400 |   input of PM in batch_quotes
# 17:42:37.089 |   input of PSX in batch_quotes
# 17:42:40.135 |   input of PNW in batch_quotes
# 17:42:52.636 |   input of PNC in batch_quotes
# 17:43:02.709 |   input of POOL in batch_quotes
# 17:43:08.503 |   input of PPG in batch_quotes
# 17:43:16.122 |   input of PPL in batch_quotes
# 17:43:24.303 |   input of PFG in batch_quotes
# 17:43:28.639 |   input of PG in batch_quotes
# 17:43:39.756 |   input of PGR in batch_quotes
# 17:43:48.268 |   input of PLD in batch_quotes
# 17:43:53.144 |   input of PRU in batch_quotes
# 17:43:57.386 |   input of PEG in batch_quotes
# 17:44:07.184 |   input of PTC in batch_quotes
# 17:44:15.123 |   input of PSA in batch_quotes
# 17:44:23.402 |   input of PHM in batch_quotes
# 17:44:31.602 |   input of PWR in batch_quotes
# 17:44:37.741 |   input of QCOM in batch_quotes
# 17:44:43.503 |   input of DGX in batch_quotes
# 17:44:48.490 |   input of RL in batch_quotes
# 17:44:53.092 |   input of RJF in batch_quotes
# 17:44:59.995 |   input of RTX in batch_quotes
# 17:45:10.697 |   input of O in batch_quotes
# 17:45:17.116 |   input of REG in batch_quotes
# 17:45:23.397 |   input of REGN in batch_quotes
# 17:45:29.809 |   input of RF in batch_quotes
# 17:45:38.552 |   input of RSG in batch_quotes
# 17:45:43.240 |   input of RMD in batch_quotes
# 17:45:48.664 |   input of RVTY in batch_quotes
# 17:45:57.562 |   input of ROK in batch_quotes
# 17:46:05.553 |   input of ROL in batch_quotes
# 17:46:13.819 |   input of ROP in batch_quotes
# 17:46:19.712 |   input of ROST in batch_quotes
# 17:46:26.829 |   input of RCL in batch_quotes
# 17:46:32.496 |   input of SPGI in batch_quotes
# 17:46:40.841 |   input of CRM in batch_quotes
# 17:46:44.454 |   input of SBAC in batch_quotes
# 17:46:49.051 |   input of SLB in batch_quotes
# 17:46:56.429 |   input of STX in batch_quotes
# 17:47:01.296 |   input of SRE in batch_quotes
# 17:47:06.103 |   input of NOW in batch_quotes
# 17:47:08.749 |   input of SHW in batch_quotes
# 17:47:17.224 |   input of SPG in batch_quotes
# 17:47:22.977 |   input of SWKS in batch_quotes
# 17:47:29.962 |   input of SJM in batch_quotes
# 17:47:35.865 |   input of SW in batch_quotes
# 17:47:36.935 |   input of SNA in batch_quotes
# 17:47:45.733 |   input of SOLV in batch_quotes
# 17:47:46.452 |   input of SO in batch_quotes
# 17:47:53.606 |   input of LUV in batch_quotes
# 17:48:01.879 |   input of SWK in batch_quotes
# 17:48:09.745 |   input of SBUX in batch_quotes
# 17:48:15.608 |   input of STT in batch_quotes
# 17:48:23.377 |   input of STLD in batch_quotes
# 17:48:29.117 |   input of STE in batch_quotes
# 17:48:35.235 |   input of SYK in batch_quotes
# 17:48:42.771 |   input of SMCI in batch_quotes
# 17:48:46.209 |   input of SYF in batch_quotes
# 17:48:48.393 |   input of SNPS in batch_quotes
# 17:48:54.014 |   input of SYY in batch_quotes
# 17:49:02.729 |   input of TMUS in batch_quotes
# 17:49:06.130 |   input of TROW in batch_quotes
# 17:49:12.882 |   input of TTWO in batch_quotes
# 17:49:18.825 |   input of TPR in batch_quotes
# 17:49:23.475 |   input of TRGP in batch_quotes
# 17:49:23.875 |   input of TGT in batch_quotes
# 17:49:33.079 |   input of TEL in batch_quotes
# 17:49:36.340 |   input of TDY in batch_quotes
# 17:49:40.524 |   input of TER in batch_quotes
# 17:49:48.365 |   input of TSLA in batch_quotes
# 17:49:51.014 |   input of TXN in batch_quotes
# 17:50:00.376 |   input of TPL in batch_quotes
# 17:50:08.731 |   input of TXT in batch_quotes
# 17:50:17.209 |   input of TMO in batch_quotes
# 17:50:24.382 |   input of TJX in batch_quotes
# 17:50:30.925 |   input of TKO in batch_quotes
# 17:50:35.857 |   input of TTD in batch_quotes
# 17:50:38.301 |   input of TSCO in batch_quotes
# 17:50:43.893 |   input of TT in batch_quotes
# 17:50:51.484 |   input of TDG in batch_quotes
# 17:50:54.980 |   input of TRV in batch_quotes
# 17:51:03.961 |   input of TRMB in batch_quotes
# 17:51:09.965 |   input of TFC in batch_quotes
# 17:51:17.449 |   input of TYL in batch_quotes
# 17:51:25.092 |   input of TSN in batch_quotes
# 17:51:33.223 |   input of USB in batch_quotes
# 17:51:41.491 |   input of UBER in batch_quotes
# 17:51:42.902 |   input of UDR in batch_quotes
# 17:51:50.002 |   input of ULTA in batch_quotes
# 17:51:53.230 |   input of UNP in batch_quotes
# 17:52:00.808 |   input of UAL in batch_quotes
# 17:52:01.239 |   input of UPS in batch_quotes
# 17:52:05.941 |   input of URI in batch_quotes
# 17:52:10.921 |   input of UNH in batch_quotes
# 17:52:18.682 |   input of UHS in batch_quotes
# 17:52:26.374 |   input of VLO in batch_quotes
# 17:52:33.931 |   input of VTR in batch_quotes
# 17:52:34.294 |   input of VLTO in batch_quotes
# 17:52:35.136 |   input of VRSN in batch_quotes
# 17:52:39.795 |   input of VRSK in batch_quotes
# 17:52:42.745 |   input of VZ in batch_quotes
# 17:52:49.651 |   input of VRTX in batch_quotes
# 17:52:55.680 |   input of VTRS in batch_quotes
# 17:53:04.307 |   input of VICI in batch_quotes
# 17:53:06.175 |   input of V in batch_quotes
# 17:53:09.544 |   input of VST in batch_quotes
# 17:53:09.891 |   input of VMC in batch_quotes
# 17:53:18.937 |   input of WRB in batch_quotes
# 17:53:27.655 |   input of GWW in batch_quotes
# 17:53:36.684 |   input of WAB in batch_quotes
# 17:53:42.641 |   input of WMT in batch_quotes
# 17:53:51.862 |   input of DIS in batch_quotes
# 17:54:02.545 |   input of WBD in batch_quotes
# 17:54:06.161 |   input of WM in batch_quotes
# 17:54:12.265 |   input of WAT in batch_quotes
# 17:54:17.406 |   input of WEC in batch_quotes
# 17:54:25.939 |   input of WFC in batch_quotes
# 17:54:35.423 |   input of WELL in batch_quotes
# 17:54:43.720 |   input of WST in batch_quotes
# 17:54:51.108 |   input of WDC in batch_quotes
# 17:54:58.847 |   input of WY in batch_quotes
# 17:55:07.454 |   input of WSM in batch_quotes
# 17:55:14.453 |   input of WMB in batch_quotes
# 17:55:21.985 |   input of WTW in batch_quotes
# 17:55:26.792 |   input of WDAY in batch_quotes
# 17:55:29.619 |   input of WYNN in batch_quotes
# 17:55:33.658 |   input of XEL in batch_quotes
# 17:55:42.294 |   input of XYL in batch_quotes
# 17:55:44.789 |   input of YUM in batch_quotes
# 17:55:49.193 |   input of ZBRA in batch_quotes
# 17:55:54.623 |   input of ZBH in batch_quotes
# 17:55:58.688 |   input of ZTS in batch_quotes
# rm: /Users/eartigau/bydoux_data//quotes/snp500_all_*.pkl: No such file or directory
# 17:56:06.212 |  MMM, sector Industrials
# 17:56:07.059 |  AOS, sector Industrials
# 17:56:07.847 |  ABT, sector Healthcare
# 17:56:08.617 |  ABBV, sector Healthcare
# 17:56:09.453 |  ACN, sector Technology
# 17:56:10.209 |  ADBE, sector Technology
# 17:56:11.070 |  AMD, sector Technology
# 17:56:11.811 |  AES, sector Utilities
# 17:56:12.553 |  AFL, sector Financial Services
# 17:56:13.584 |  A, sector Healthcare
# 17:56:14.554 |  APD, sector Basic Materials
# /Users/eartigau/miniconda/envs/p3.12/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3502: RuntimeWarning: Mean of empty slice.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /Users/eartigau/miniconda/envs/p3.12/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 17:56:15.516 |  ABNB, sector Consumer Cyclical
# 17:56:16.271 |  AKAM, sector Technology
# 17:56:17.171 |  ALB, sector Basic Materials
# 17:56:17.946 |  ARE, sector Real Estate
# 17:56:18.877 |  ALGN, sector Healthcare
# 17:56:19.743 |  ALLE, sector Industrials
# 17:56:20.496 |  LNT, sector Utilities
# 17:56:21.481 |  ALL, sector Financial Services
# 17:56:22.229 |  GOOGL, sector Communication Services
# 17:56:22.982 |  GOOG, sector Communication Services
# 17:56:23.709 |  MO, sector Consumer Defensive
# 17:56:24.608 |  AMZN, sector Consumer Cyclical
# 17:56:25.327 |  AMCR, sector Consumer Cyclical
# 17:56:26.168 |  AEE, sector Utilities
# 17:56:26.991 |  AEP, sector Utilities
# 17:56:27.820 |  AXP, sector Financial Services
# 17:56:28.539 |  AIG, sector Financial Services
# 17:56:29.330 |  AMT, sector Real Estate
# 17:56:30.171 |  AWK, sector Utilities
# 18:04:22.620 |  NEM	gain/45 days : 1.00 	 gain/year : 1.00 	 slope : 1.25 	 sigma : 0.04 	 qual : 30.40
# 18:04:22.620 |  Sector : Basic Materials
# 18:04:22.621 |  GEV	gain/45 days : 1.00 	 gain/year : 1.00 	 slope : 1.21 	 sigma : 0.08 	 qual : 14.33
# 18:04:22.621 |  Sector : Industrials
# 18:04:22.622 |  RCL	gain/45 days : 1.00 	 gain/year : 1.00 	 slope : 1.13 	 sigma : 0.10 	 qual : 11.39
# 18:04:22.623 |  Sector : Consumer Cyclical
# 18:04:22.623 |  WYNN	gain/45 days : 1.00 	 gain/year : 1.00 	 slope : 0.99 	 sigma : 0.07 	 qual : 13.43
# 18:04:22.624 |  Sector : Consumer Cyclical
# 18:04:22.625 |  PSKY	gain/45 days : 1.00 	 gain/year : 1.00 	 slope : 0.94 	 sigma : 0.04 	 qual : 21.69
# 18:04:22.625 |  Sector : Communication Services
# 18:04:22.626 |  IDXX	gain/45 days : 1.00 	 gain/year : 1.00 	 slope : 0.90 	 sigma : 0.06 	 qual : 15.66
# 18:04:22.627 |  Sector : Healthcare
# /var/folders/cy/vv8rw3d12f31t1wpxpbdgmtm0000gp/T/ipykernel_4997/2339900810.py:266: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(t_year_plot, growth_nothing, 'r-')
# /var/folders/cy/vv8rw3d12f31t1wpxpbdgmtm0000gp/T/ipykernel_4997/2339900810.py:267: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(t_year_plot, growth_strategy, 'g-')
# /var/folders/cy/vv8rw3d12f31t1wpxpbdgmtm0000gp/T/ipykernel_4997/2339900810.py:339: DeprecationWarning: `cumproduct` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `cumprod` instead.
#   simu_sp500(nkeeps=[8], timesteps=[45], lookback_scales=[5], method='slope', injection=30000, nyears=20)
# /var/folders/cy/vv8rw3d12f31t1wpxpbdgmtm0000gp/T/ipykernel_4997/2339900810.py:294: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(t_year_plot,np.log(np.cumproduct(growth_strategy)))
# /var/folders/cy/vv8rw3d12f31t1wpxpbdgmtm0000gp/T/ipykernel_4997/2339900810.py:295: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(t_year_plot,np.log(np.cumproduct(growth_nothing)))
# 18:04:23.373 |  Mean yearly growth doing nothing : 1.17, rms : 0.14
# 18:04:23.374 |  Mean yearly growth with strategy : 1.36, rms : 0.29
# 18:04:24.061 |  Fraction 0.69 of 45 days with positive growth [113/163] -- strategy
# 18:04:24.062 |  Fraction 0.72 of 45 days with positive growth [117/163] -- nothing
# 18:04:24.063 |  Fraction 0.95 of yearly with positive growth [20/21] -- strategy
# 18:04:24.063 |  Fraction 0.81 of yearly with positive growth [17/21] -- nothing
